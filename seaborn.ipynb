# %%
# !pip install seaborn

# %% [markdown]
# Seaborn is child of matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Data can be read by pandas and !Seaborn! too

# %%
import seaborn as sns
df = sns.load_dataset('tips')

# %% [markdown]
# types of plot
# 1. relational
# 2. distribution
# 3. categorical
# 4. regression
# 5. matrix
# 6. multiplot

# %% [markdown]
# Relational Plot: Bw two or more variable relationship
# Bivariate
# 1. scatterplot
# 2. linearplot
# 3. barplot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.value_counts('sex')
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df.value_counts('smoker')
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df.value_counts('day')
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df.value_counts('time')
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
# Scatterplot

# %%
sns.scatterplot(x='total_bill',y='tip',data=df,hue='time',style='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# lineplot

# %%
marks = [60,70,75,80,85,90,95]
days = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']

# %%
sns.lineplot(x='Day', y='Marks', data=plot_df)
# Out:
# <Axes: xlabel='Day', ylabel='Marks'>

# %%
import pandas as pd
df2 = pd.read_csv('/content/Life Expectancy Data.csv')

# %%
df2
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
sns.lineplot(x='Year', y='Life expectancy ', data=df2)
# Out:
# <Axes: xlabel='Year', ylabel='Life expectancy '>

# %%
sns.relplot(x='Year', y='Life expectancy ', data=df2, hue='Country')

# %%
filtered_df = df2[df2['Country'].isin(['India', 'Viet Nam', 'Zambia'])]
sns.lineplot(x='Year', y='Life expectancy ', data=filtered_df, hue='Country')
# Out:
# <Axes: xlabel='Year', ylabel='Life expectancy '>

# %% [markdown]
# Distribution Plot*
# 1. sns.histplot()
# 2. sns.kdeplot()
# 3. sns.ecdfplot()

# %%
sns.histplot(df2['Polio'], kde=True)
# Out:
# <Axes: xlabel='Polio', ylabel='Count'>

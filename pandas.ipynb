# %%
print("Pandas")
# Out:
# Pandas

# %% [markdown]
# ### ! (exclamation mark) tells jupyter to run the command in terminal

# %%
# !pip install pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution ~vicorn (C:\Users\kunal\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~vicorn (C:\Users\kunal\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~vicorn (C:\Users\kunal\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~vicorn (C:\Users\kunal\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
import pandas as pd

# %% [markdown]
# #### Key Data structures in Pandas
# ```
#     1. Series
#     2. Dataframe
# ```

# %%
series = pd.Series(["Kunal","Anshika","Surya","Tanush","Abhinav","Ishita"])

# %% [markdown]
# ``` We will have index and corresponding elements here```

# %%
series
# Out:
# 0      Kunal
# 1    Anshika
# 2      Surya
# 3     Tanush
# 4    Abhinav
# 5     Ishita
# dtype: str

# %%
df = pd.DataFrame({"names" :['Kunal','Tanish','Harshwardhan','Prachi'], "marks" :[90, 80, 70, 60]})

# %%
df
# Out:
#           names  marks
# 0         Kunal     90
# 1        Tanish     80
# 2  Harshwardhan     70
# 3        Prachi     60

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values("Ticket",ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 745          746         0       1
# 540          541         1       1
# 219          220         0       2
# 92            93         0       1
# 235          236         0       3
# ..           ...       ...     ...
# 585          586         1       1
# 262          263         0       1
# 504          505         1       1
# 257          258         1       1
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 745                       Crosby, Capt. Edward Gifford    male  70.0      1
# 540                            Crosby, Miss. Harriet R  female  36.0      0
# 219                                 Harris, Mr. Walter    male  30.0      0
# 92                         Chaffee, Mr. Herbert Fuller    male  46.0      1
# 235                       Harknett, Miss. Alice Phoebe  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values('Pclass',ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 0              1         0       3
# 888          889         0       3
# 2              3         1       3
# 885          886         0       3
# ..           ...       ...     ...
# 853          854         1       1
# 23            24         1       1
# 27            28         0       1
# 30            31         0       1
# 31            32         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 890                             Dooley, Mr. Patrick    male  32.0      0
# 0                           Braund, Mr. Owen Harris    male  22.0      1
# 888        Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 2                            Heikkinen, Miss. Laina  female  26.0      0
# 885            Rice, Mrs. William (Margaret Norton)  female  39.0      0
# ..                                              ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
